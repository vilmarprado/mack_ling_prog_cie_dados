# %% [markdown]
# <a href="https://colab.research.google.com/github/vilmarprado/mack_ling_prog_cie_dados/blob/main/Consulta_Cri_cra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6cd77b05-87a5-49fd-b78b-9d34dc839484" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cd77b05-87a5-49fd-b78b-9d34dc839484">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['precos-cri-cra.csv']),sep=';', encoding='latin-1')

print(df)
df.head()
# Out:
#     Data de Referência                                   Risco de Crédito   \
# 0            29/09/2023                          CYRELA BRAZIL REALTY S.A.
# 1            29/09/2023                       PETROBRAS DISTRIBUIDORA S.A.
# 2            29/09/2023                                RAÍZEN ENERGIA S.A.
# 3            29/09/2023                MRV ENGENHARIA E PARTICIPAÇÕES S.A.
# 4            29/09/2023                               CAMIL ALIMENTOS S.A.
# ..                  ...                                                ...
# 825          25/09/2023  FS AGRISOLUTIONS INDÚSTRIA DE BIOCOMBUSTÍVEIS ...
# 826          25/09/2023  FS AGRISOLUTIONS INDÚSTRIA DE BIOCOMBUSTÍVEIS ...
# 827          25/09/2023                     LAR COOPERATIVA AGROINDUSTRIAL
# 828          25/09/2023                                 ÂNIMA HOLDING S.A.
# 829          25/09/2023         ADUBOS ARAGUAIA INDÚSTRIA E COMÉRCIO LTDA.
#
# ...
